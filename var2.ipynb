# %% [markdown]
# ## Variant 2: Remove the maxpool layers. Using stride=2 in the conv layer before the maxpool to achieve similar size reduction. Would the performance improve?

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split, Subset
from torchvision import datasets
from torch.utils.data.dataset import Dataset
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

# %%
class TransformDataset(Dataset):
    
    def __init__(self, dataset, transform=None):
        self.dataset = dataset
        self.transform = transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# Define transformations
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load CIFAR-10 dataset
full_train_set = datasets.CIFAR10(root='./data', train=True, download=True)
test_set = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# Split the full training dataset into new training and validation datasets (80/20 split)
train_size = int(0.8 * len(full_train_set))
val_size = len(full_train_set) - train_size
train_indices, val_indices = torch.utils.data.random_split(range(len(full_train_set)), [train_size, val_size])

train_dataset = TransformDataset(Subset(full_train_set, train_indices), transform=transform_train)
val_dataset = TransformDataset(Subset(full_train_set, val_indices), transform=transform)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class MiniVGGVar2(nn.Module):
    def __init__(self):
        super(MiniVGGVar2, self).__init__()

        # First convolutional block
        self.conv1_1 = nn.Conv2d(3, 64, 3, padding=1)
        self.bn1_1 = nn.BatchNorm2d(64)
        self.conv1_2 = nn.Conv2d(64, 64, 3, padding=1, stride=2)  # Apply stride = 2
        self.bn1_2 = nn.BatchNorm2d(64)
        # Removed pooling layer

        # Second convolutional block
        self.conv2_1 = nn.Conv2d(64, 128, 3, padding=1)
        self.bn2_1 = nn.BatchNorm2d(128)
        self.conv2_2 = nn.Conv2d(128, 128, 3, padding=1, stride=2)  # Apply stride= 2
        self.bn2_2 = nn.BatchNorm2d(128)
        # Removed pooling layer

        # Third convolutional block
        self.conv3_1 = nn.Conv2d(128, 256, 3, padding=1)
        self.bn3_1 = nn.BatchNorm2d(256)
        self.conv3_2 = nn.Conv2d(256, 256, 3, padding=1, stride=2)  # Apply stride =2
        self.bn3_2 = nn.BatchNorm2d(256)
        # Removed pooling layer

        # Fully connected layers
        self.dropout = nn.Dropout(0.3)
        self.fc1 = nn.Linear(256 * 4 * 4, 512)  
        self.fc2 = nn.Linear(512, 10)  

    def forward(self, x):
        # Each convolutional block
        x = F.selu(self.bn1_1(self.conv1_1(x)))
        x = F.selu(self.bn1_2(self.conv1_2(x)))

        x = F.selu(self.bn2_1(self.conv2_1(x)))
        x = F.selu(self.bn2_2(self.conv2_2(x)))

        x = F.selu(self.bn3_1(self.conv3_1(x)))
        x = F.selu(self.bn3_2(self.conv3_2(x)))

        # Flatten and pass through dense layers with dropout in between
        x = x.view(-1, 256 * 4 * 4)
        x = self.dropout(x)
        x = F.selu(self.fc1(x))
        x = self.fc2(x)

        return x

model = MiniVGGVar2()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# Loss function and optimizer with weight decay
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, weight_decay=0.008) 

# Initialize the StepLR scheduler
scheduler = StepLR(optimizer, step_size=20, gamma=0.3)

# Device configuration
device = torch.device("cuda")
model.to(device)

def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs=70):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        total_samples = 0
        running_loss = 0.0
        running_correct = 0

        # Training phase
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs, 1)
            running_correct += (predicted == labels).sum().item()
            total_samples += labels.size(0)

        epoch_train_loss = running_loss / total_samples
        epoch_train_acc = running_correct / total_samples
        train_losses.append(epoch_train_loss)
        train_accuracies.append(epoch_train_acc * 100)

        # Validation phase
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                _, predicted = torch.max(outputs.data, 1)
                val_correct += (predicted == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_loss = val_loss / val_total
        epoch_val_acc = val_correct / val_total
        val_losses.append(epoch_val_loss)
        val_accuracies.append(epoch_val_acc * 100)

        # Print training and validation results
        print(f'Epoch [{epoch+1}/{num_epochs}]: Train Loss: {epoch_train_loss:.4f}, Train Acc: {epoch_train_acc * 100:.2f}%, Val Loss: {epoch_val_loss:.4f}, Val Acc: {epoch_val_acc * 100:.2f}%')

        # Update the learning rate
        scheduler.step()

    return train_losses, val_losses, train_accuracies, val_accuracies

train_losses, val_losses, train_accuracies, val_accuracies = train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs=70)
# Out:
# Epoch [1/70]: Train Loss: 1.7940, Train Acc: 36.55%, Val Loss: 1.6208, Val Acc: 43.18%
# Epoch [2/70]: Train Loss: 1.5293, Train Acc: 45.54%, Val Loss: 1.4364, Val Acc: 49.06%
# Epoch [3/70]: Train Loss: 1.4213, Train Acc: 49.36%, Val Loss: 1.3556, Val Acc: 52.48%
# Epoch [4/70]: Train Loss: 1.3539, Train Acc: 51.49%, Val Loss: 1.3054, Val Acc: 54.18%
# Epoch [5/70]: Train Loss: 1.3077, Train Acc: 53.65%, Val Loss: 1.2931, Val Acc: 54.66%
# Epoch [6/70]: Train Loss: 1.2674, Train Acc: 54.92%, Val Loss: 1.2763, Val Acc: 55.16%
# Epoch [7/70]: Train Loss: 1.2347, Train Acc: 56.03%, Val Loss: 1.2231, Val Acc: 56.66%
# Epoch [8/70]: Train Loss: 1.2020, Train Acc: 57.54%, Val Loss: 1.2010, Val Acc: 57.73%
# Epoch [9/70]: Train Loss: 1.1740, Train Acc: 58.53%, Val Loss: 1.1950, Val Acc: 57.90%
# Epoch [10/70]: Train Loss: 1.1465, Train Acc: 59.59%, Val Loss: 1.2168, Val Acc: 57.59%
# Epoch [11/70]: Train Loss: 1.1179, Train Acc: 60.59%, Val Loss: 1.1239, Val Acc: 61.39%
# Epoch [12/70]: Train Loss: 1.0954, Train Acc: 61.44%, Val Loss: 1.1238, Val Acc: 60.70%
# Epoch [13/70]: Train Loss: 1.0741, Train Acc: 62.38%, Val Loss: 1.1380, Val Acc: 59.94%
# Epoch [14/70]: Train Loss: 1.0449, Train Acc: 63.37%, Val Loss: 1.0759, Val Acc: 62.69%
# Epoch [15/70]: Train Loss: 1.0260, Train Acc: 63.98%, Val Loss: 1.0685, Val Acc: 62.31%
# Epoch [16/70]: Train Loss: 1.0078, Train Acc: 64.71%, Val Loss: 1.1305, Val Acc: 60.73%
# Epoch [17/70]: Train Loss: 0.9899, Train Acc: 65.41%, Val Loss: 1.0368, Val Acc: 63.89%
# Epoch [18/70]: Train Loss: 0.9765, Train Acc: 65.93%, Val Loss: 1.0537, Val Acc: 62.66%
# Epoch [19/70]: Train Loss: 0.9574, Train Acc: 66.58%, Val Loss: 1.0606, Val Acc: 63.30%
# Epoch [20/70]: Train Loss: 0.9486, Train Acc: 66.77%, Val Loss: 0.9820, Val Acc: 65.92%
# Epoch [21/70]: Train Loss: 0.8843, Train Acc: 69.45%, Val Loss: 0.9425, Val Acc: 67.09%
# Epoch [22/70]: Train Loss: 0.8739, Train Acc: 69.91%, Val Loss: 0.9478, Val Acc: 66.89%
# Epoch [23/70]: Train Loss: 0.8697, Train Acc: 69.87%, Val Loss: 0.9511, Val Acc: 66.72%
# Epoch [24/70]: Train Loss: 0.8599, Train Acc: 70.17%, Val Loss: 0.9373, Val Acc: 67.49%
# Epoch [25/70]: Train Loss: 0.8578, Train Acc: 70.28%, Val Loss: 0.9276, Val Acc: 67.47%
# Epoch [26/70]: Train Loss: 0.8547, Train Acc: 70.42%, Val Loss: 0.9485, Val Acc: 67.04%
# Epoch [27/70]: Train Loss: 0.8491, Train Acc: 70.67%, Val Loss: 0.9224, Val Acc: 67.82%
# Epoch [28/70]: Train Loss: 0.8436, Train Acc: 70.85%, Val Loss: 0.9360, Val Acc: 66.96%
# Epoch [29/70]: Train Loss: 0.8401, Train Acc: 71.07%, Val Loss: 0.9167, Val Acc: 68.46%
# Epoch [30/70]: Train Loss: 0.8359, Train Acc: 71.09%, Val Loss: 0.9313, Val Acc: 67.74%
# Epoch [31/70]: Train Loss: 0.8345, Train Acc: 71.20%, Val Loss: 0.9051, Val Acc: 68.44%
# Epoch [32/70]: Train Loss: 0.8266, Train Acc: 71.35%, Val Loss: 0.9123, Val Acc: 68.36%
# Epoch [33/70]: Train Loss: 0.8223, Train Acc: 71.53%, Val Loss: 0.9054, Val Acc: 68.47%
# Epoch [34/70]: Train Loss: 0.8192, Train Acc: 71.57%, Val Loss: 0.9178, Val Acc: 68.24%
# Epoch [35/70]: Train Loss: 0.8165, Train Acc: 71.77%, Val Loss: 0.9148, Val Acc: 68.09%
# Epoch [36/70]: Train Loss: 0.8119, Train Acc: 72.00%, Val Loss: 0.9262, Val Acc: 68.05%
# Epoch [37/70]: Train Loss: 0.8069, Train Acc: 72.10%, Val Loss: 0.9133, Val Acc: 68.35%
# Epoch [38/70]: Train Loss: 0.8016, Train Acc: 72.19%, Val Loss: 0.9106, Val Acc: 68.16%
# Epoch [39/70]: Train Loss: 0.7974, Train Acc: 72.47%, Val Loss: 0.9426, Val Acc: 67.03%
# Epoch [40/70]: Train Loss: 0.7989, Train Acc: 72.30%, Val Loss: 0.9726, Val Acc: 66.20%
# Epoch [41/70]: Train Loss: 0.7686, Train Acc: 73.48%, Val Loss: 0.8779, Val Acc: 69.76%
# Epoch [42/70]: Train Loss: 0.7704, Train Acc: 73.72%, Val Loss: 0.8748, Val Acc: 69.54%
# Epoch [43/70]: Train Loss: 0.7618, Train Acc: 73.88%, Val Loss: 0.8738, Val Acc: 70.01%
# Epoch [44/70]: Train Loss: 0.7619, Train Acc: 73.83%, Val Loss: 0.8811, Val Acc: 69.55%
# Epoch [45/70]: Train Loss: 0.7632, Train Acc: 73.88%, Val Loss: 0.8710, Val Acc: 69.90%
# Epoch [46/70]: Train Loss: 0.7624, Train Acc: 73.74%, Val Loss: 0.8718, Val Acc: 69.79%
# Epoch [47/70]: Train Loss: 0.7566, Train Acc: 74.08%, Val Loss: 0.8745, Val Acc: 69.75%
# Epoch [48/70]: Train Loss: 0.7603, Train Acc: 73.99%, Val Loss: 0.8717, Val Acc: 69.95%
# Epoch [49/70]: Train Loss: 0.7549, Train Acc: 74.18%, Val Loss: 0.8747, Val Acc: 69.65%
# Epoch [50/70]: Train Loss: 0.7511, Train Acc: 74.02%, Val Loss: 0.8690, Val Acc: 69.61%
# Epoch [51/70]: Train Loss: 0.7539, Train Acc: 74.17%, Val Loss: 0.8797, Val Acc: 69.62%
# Epoch [52/70]: Train Loss: 0.7542, Train Acc: 74.13%, Val Loss: 0.8756, Val Acc: 69.52%
# Epoch [53/70]: Train Loss: 0.7523, Train Acc: 74.19%, Val Loss: 0.8663, Val Acc: 69.87%
# Epoch [54/70]: Train Loss: 0.7491, Train Acc: 74.03%, Val Loss: 0.8737, Val Acc: 69.89%
# Epoch [55/70]: Train Loss: 0.7483, Train Acc: 74.19%, Val Loss: 0.8691, Val Acc: 69.73%
# Epoch [56/70]: Train Loss: 0.7451, Train Acc: 74.50%, Val Loss: 0.8634, Val Acc: 70.00%
# Epoch [57/70]: Train Loss: 0.7454, Train Acc: 74.34%, Val Loss: 0.8731, Val Acc: 69.73%
# Epoch [58/70]: Train Loss: 0.7446, Train Acc: 74.35%, Val Loss: 0.8666, Val Acc: 69.66%
# Epoch [59/70]: Train Loss: 0.7397, Train Acc: 74.69%, Val Loss: 0.8607, Val Acc: 70.07%
# Epoch [60/70]: Train Loss: 0.7422, Train Acc: 74.44%, Val Loss: 0.8637, Val Acc: 70.02%
# Epoch [61/70]: Train Loss: 0.7351, Train Acc: 74.76%, Val Loss: 0.8554, Val Acc: 70.24%
# Epoch [62/70]: Train Loss: 0.7312, Train Acc: 74.82%, Val Loss: 0.8570, Val Acc: 70.21%
# Epoch [63/70]: Train Loss: 0.7326, Train Acc: 74.90%, Val Loss: 0.8572, Val Acc: 70.47%
# Epoch [64/70]: Train Loss: 0.7314, Train Acc: 74.91%, Val Loss: 0.8561, Val Acc: 70.35%
# Epoch [65/70]: Train Loss: 0.7288, Train Acc: 74.95%, Val Loss: 0.8550, Val Acc: 70.42%
# Epoch [66/70]: Train Loss: 0.7283, Train Acc: 75.14%, Val Loss: 0.8541, Val Acc: 70.56%
# Epoch [67/70]: Train Loss: 0.7308, Train Acc: 74.98%, Val Loss: 0.8538, Val Acc: 70.32%
# Epoch [68/70]: Train Loss: 0.7303, Train Acc: 75.11%, Val Loss: 0.8581, Val Acc: 70.34%
# Epoch [69/70]: Train Loss: 0.7283, Train Acc: 75.18%, Val Loss: 0.8550, Val Acc: 70.33%
# Epoch [70/70]: Train Loss: 0.7290, Train Acc: 75.16%, Val Loss: 0.8526, Val Acc: 70.47%

# %%
import matplotlib.pyplot as plt

def plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Training vs Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Training Accuracy')
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.show()

plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies)

# %% [markdown]
# #### Test Accuracy for Variant 2

# %%
model.eval()  # Set the model to evaluation mode
test_corrects = 0

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        test_corrects += torch.sum(preds == labels.data)

test_acc = test_corrects.double() / len(test_set)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# Test Accuracy: 0.7030

# %% [markdown]
# ### Observation:
#
# The training is not as stable as the original vgg and also the test accuracy has reduced. This suggests that the overall performance has not improved .
