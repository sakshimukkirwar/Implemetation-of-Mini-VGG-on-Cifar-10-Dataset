# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split, Subset
from torchvision import datasets
from torch.utils.data.dataset import Dataset
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt

# %%
class TransformDataset(Dataset):
    
    def __init__(self, dataset, transform=None):
        self.dataset = dataset
        self.transform = transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# Define transformations
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load CIFAR-10 dataset
full_train_set = datasets.CIFAR10(root='./data', train=True, download=True)
test_set = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# Split the full training dataset into new training and validation datasets (80/20 split)
train_size = int(0.8 * len(full_train_set))
val_size = len(full_train_set) - train_size
train_indices, val_indices = torch.utils.data.random_split(range(len(full_train_set)), [train_size, val_size])

train_dataset = TransformDataset(Subset(full_train_set, train_indices), transform=transform_train)
val_dataset = TransformDataset(Subset(full_train_set, val_indices), transform=transform)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class MiniVGG(nn.Module):
    def __init__(self):
        super(MiniVGG, self).__init__()

        # First convolutional block
        self.conv1_1 = nn.Conv2d(3, 64, 3, padding=1)
        self.bn1_1 = nn.BatchNorm2d(64)
        self.conv1_2 = nn.Conv2d(64, 64, 3, padding=1)
        self.bn1_2 = nn.BatchNorm2d(64)
        self.pool1 = nn.MaxPool2d(2, 2)

        # Second convolutional block
        self.conv2_1 = nn.Conv2d(64, 128, 3, padding=1)
        self.bn2_1 = nn.BatchNorm2d(128)
        self.conv2_2 = nn.Conv2d(128, 128, 3, padding=1)
        self.bn2_2 = nn.BatchNorm2d(128)
        self.pool2 = nn.MaxPool2d(2, 2)

        # Third convolutional block
        self.conv3_1 = nn.Conv2d(128, 256, 3, padding=1)
        self.bn3_1 = nn.BatchNorm2d(256)
        self.conv3_2 = nn.Conv2d(256, 256, 3, padding=1)
        self.bn3_2 = nn.BatchNorm2d(256)
        self.pool3 = nn.MaxPool2d(2, 2)

        # Fully connected layers
        self.dropout = nn.Dropout(0.3)
        self.fc1 = nn.Linear(256 * 4 * 4, 512)
        self.fc2 = nn.Linear(512, 10)  

    def forward(self, x):
        # Each convolutional block followed by pooling
        x = F.relu(self.bn1_1(self.conv1_1(x)))
        x = self.pool1(F.relu(self.bn1_2(self.conv1_2(x))))

        x = F.relu(self.bn2_1(self.conv2_1(x)))
        x = self.pool2(F.relu(self.bn2_2(self.conv2_2(x))))

        x = F.relu(self.bn3_1(self.conv3_1(x)))
        x = self.pool3(F.relu(self.bn3_2(self.conv3_2(x))))

        # Flatten and pass through dense layers with dropout in between
        x = x.view(-1, 256 * 4 * 4)
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x
    
model = MiniVGG()

# %%
# Loss function and optimizer with weight decay
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.0008, weight_decay=0.005)  
scheduler = StepLR(optimizer, step_size= 20 , gamma=0.3)


# Device configuration
device = torch.device("cuda")
model.to(device)

def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs=120):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        total_samples = 0
        running_loss = 0.0
        running_correct = 0

        # Training phase
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs, 1)
            running_correct += (predicted == labels).sum().item()
            total_samples += labels.size(0)

        epoch_train_loss = running_loss / total_samples
        epoch_train_acc = running_correct / total_samples
        train_losses.append(epoch_train_loss)
        train_accuracies.append(epoch_train_acc * 100)

        # Validation phase
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                _, predicted = torch.max(outputs.data, 1)
                val_correct += (predicted == labels).sum().item()
                val_total += labels.size(0)

        epoch_val_loss = val_loss / val_total
        epoch_val_acc = val_correct / val_total
        val_losses.append(epoch_val_loss)
        val_accuracies.append(epoch_val_acc * 100)

        # Print training and validation results
        print(f'Epoch [{epoch+1}/{num_epochs}]: Train Loss: {epoch_train_loss:.4f}, Train Acc: {epoch_train_acc * 100:.2f}%, Val Loss: {epoch_val_loss:.4f}, Val Acc: {epoch_val_acc * 100:.2f}%')
        
        # Update the learning rate
        scheduler.step()

    return train_losses, val_losses, train_accuracies, val_accuracies

# Start training with scheduler
train_losses, val_losses, train_accuracies, val_accuracies = train_model(model, train_loader, val_loader, criterion, optimizer, scheduler)
# Out:
# Epoch [1/120]: Train Loss: 1.9555, Train Acc: 30.74%, Val Loss: 1.6522, Val Acc: 42.33%
# Epoch [2/120]: Train Loss: 1.5693, Train Acc: 43.97%, Val Loss: 1.4203, Val Acc: 49.61%
# Epoch [3/120]: Train Loss: 1.3932, Train Acc: 50.38%, Val Loss: 1.3026, Val Acc: 53.47%
# Epoch [4/120]: Train Loss: 1.2863, Train Acc: 54.05%, Val Loss: 1.2126, Val Acc: 56.85%
# Epoch [5/120]: Train Loss: 1.2022, Train Acc: 57.44%, Val Loss: 1.1345, Val Acc: 59.83%
# Epoch [6/120]: Train Loss: 1.1268, Train Acc: 60.09%, Val Loss: 1.0686, Val Acc: 62.15%
# Epoch [7/120]: Train Loss: 1.0604, Train Acc: 62.45%, Val Loss: 1.0256, Val Acc: 63.53%
# Epoch [8/120]: Train Loss: 1.0030, Train Acc: 64.72%, Val Loss: 0.9750, Val Acc: 65.41%
# Epoch [9/120]: Train Loss: 0.9547, Train Acc: 66.47%, Val Loss: 0.9384, Val Acc: 66.15%
# Epoch [10/120]: Train Loss: 0.9159, Train Acc: 67.85%, Val Loss: 0.8914, Val Acc: 68.55%
# Epoch [11/120]: Train Loss: 0.8741, Train Acc: 69.36%, Val Loss: 0.8723, Val Acc: 69.09%
# Epoch [12/120]: Train Loss: 0.8351, Train Acc: 71.02%, Val Loss: 0.8752, Val Acc: 69.52%
# Epoch [13/120]: Train Loss: 0.8094, Train Acc: 71.89%, Val Loss: 0.8439, Val Acc: 69.86%
# Epoch [14/120]: Train Loss: 0.7838, Train Acc: 72.69%, Val Loss: 0.8058, Val Acc: 71.40%
# Epoch [15/120]: Train Loss: 0.7558, Train Acc: 73.98%, Val Loss: 0.7911, Val Acc: 72.06%
# Epoch [16/120]: Train Loss: 0.7300, Train Acc: 74.82%, Val Loss: 0.7580, Val Acc: 73.31%
# Epoch [17/120]: Train Loss: 0.7094, Train Acc: 75.47%, Val Loss: 0.7676, Val Acc: 72.63%
# Epoch [18/120]: Train Loss: 0.6897, Train Acc: 76.42%, Val Loss: 0.7330, Val Acc: 74.05%
# Epoch [19/120]: Train Loss: 0.6690, Train Acc: 76.93%, Val Loss: 0.7494, Val Acc: 73.75%
# Epoch [20/120]: Train Loss: 0.6539, Train Acc: 77.21%, Val Loss: 0.7172, Val Acc: 74.82%
# Epoch [21/120]: Train Loss: 0.6195, Train Acc: 78.68%, Val Loss: 0.6955, Val Acc: 75.68%
# Epoch [22/120]: Train Loss: 0.6079, Train Acc: 79.16%, Val Loss: 0.6953, Val Acc: 75.58%
# Epoch [23/120]: Train Loss: 0.6021, Train Acc: 79.15%, Val Loss: 0.6902, Val Acc: 75.85%
# Epoch [24/120]: Train Loss: 0.5952, Train Acc: 79.63%, Val Loss: 0.6831, Val Acc: 76.20%
# Epoch [25/120]: Train Loss: 0.5911, Train Acc: 79.72%, Val Loss: 0.6774, Val Acc: 76.29%
# Epoch [26/120]: Train Loss: 0.5846, Train Acc: 79.89%, Val Loss: 0.6843, Val Acc: 76.09%
# Epoch [27/120]: Train Loss: 0.5792, Train Acc: 79.95%, Val Loss: 0.6749, Val Acc: 76.59%
# Epoch [28/120]: Train Loss: 0.5739, Train Acc: 80.17%, Val Loss: 0.6771, Val Acc: 76.28%
# Epoch [29/120]: Train Loss: 0.5676, Train Acc: 80.51%, Val Loss: 0.6685, Val Acc: 76.84%
# Epoch [30/120]: Train Loss: 0.5666, Train Acc: 80.62%, Val Loss: 0.6687, Val Acc: 76.63%
# Epoch [31/120]: Train Loss: 0.5587, Train Acc: 80.92%, Val Loss: 0.6665, Val Acc: 76.76%
# Epoch [32/120]: Train Loss: 0.5537, Train Acc: 80.94%, Val Loss: 0.6620, Val Acc: 76.96%
# Epoch [33/120]: Train Loss: 0.5493, Train Acc: 81.14%, Val Loss: 0.6593, Val Acc: 76.79%
# Epoch [34/120]: Train Loss: 0.5475, Train Acc: 81.23%, Val Loss: 0.6573, Val Acc: 77.05%
# Epoch [35/120]: Train Loss: 0.5414, Train Acc: 81.40%, Val Loss: 0.6570, Val Acc: 77.01%
# Epoch [36/120]: Train Loss: 0.5356, Train Acc: 81.76%, Val Loss: 0.6496, Val Acc: 77.36%
# Epoch [37/120]: Train Loss: 0.5302, Train Acc: 81.89%, Val Loss: 0.6557, Val Acc: 77.25%
# Epoch [38/120]: Train Loss: 0.5244, Train Acc: 82.19%, Val Loss: 0.6498, Val Acc: 77.55%
# Epoch [39/120]: Train Loss: 0.5207, Train Acc: 82.33%, Val Loss: 0.6519, Val Acc: 76.99%
# Epoch [40/120]: Train Loss: 0.5157, Train Acc: 82.51%, Val Loss: 0.6442, Val Acc: 77.73%
# Epoch [41/120]: Train Loss: 0.5025, Train Acc: 82.85%, Val Loss: 0.6373, Val Acc: 77.75%
# Epoch [42/120]: Train Loss: 0.5024, Train Acc: 82.69%, Val Loss: 0.6373, Val Acc: 77.76%
# Epoch [43/120]: Train Loss: 0.5033, Train Acc: 82.88%, Val Loss: 0.6356, Val Acc: 77.79%
# Epoch [44/120]: Train Loss: 0.4987, Train Acc: 83.15%, Val Loss: 0.6368, Val Acc: 77.63%
# Epoch [45/120]: Train Loss: 0.4966, Train Acc: 83.09%, Val Loss: 0.6349, Val Acc: 77.91%
# Epoch [46/120]: Train Loss: 0.4937, Train Acc: 83.15%, Val Loss: 0.6345, Val Acc: 77.88%
# Epoch [47/120]: Train Loss: 0.4949, Train Acc: 83.34%, Val Loss: 0.6345, Val Acc: 78.02%
# Epoch [48/120]: Train Loss: 0.4943, Train Acc: 83.20%, Val Loss: 0.6331, Val Acc: 77.77%
# Epoch [49/120]: Train Loss: 0.4916, Train Acc: 83.23%, Val Loss: 0.6340, Val Acc: 77.80%
# Epoch [50/120]: Train Loss: 0.4888, Train Acc: 83.45%, Val Loss: 0.6316, Val Acc: 77.90%
# Epoch [51/120]: Train Loss: 0.4872, Train Acc: 83.50%, Val Loss: 0.6330, Val Acc: 77.88%
# Epoch [52/120]: Train Loss: 0.4866, Train Acc: 83.51%, Val Loss: 0.6297, Val Acc: 78.01%
# Epoch [53/120]: Train Loss: 0.4822, Train Acc: 83.52%, Val Loss: 0.6310, Val Acc: 78.21%
# Epoch [54/120]: Train Loss: 0.4837, Train Acc: 83.52%, Val Loss: 0.6303, Val Acc: 78.05%
# Epoch [55/120]: Train Loss: 0.4850, Train Acc: 83.61%, Val Loss: 0.6307, Val Acc: 78.16%
# Epoch [56/120]: Train Loss: 0.4817, Train Acc: 83.69%, Val Loss: 0.6288, Val Acc: 77.99%
# Epoch [57/120]: Train Loss: 0.4784, Train Acc: 83.71%, Val Loss: 0.6285, Val Acc: 78.05%
# Epoch [58/120]: Train Loss: 0.4777, Train Acc: 83.73%, Val Loss: 0.6272, Val Acc: 78.02%
# Epoch [59/120]: Train Loss: 0.4777, Train Acc: 83.70%, Val Loss: 0.6289, Val Acc: 78.01%
# Epoch [60/120]: Train Loss: 0.4781, Train Acc: 83.81%, Val Loss: 0.6256, Val Acc: 78.11%
# Epoch [61/120]: Train Loss: 0.4697, Train Acc: 84.10%, Val Loss: 0.6259, Val Acc: 78.09%
# Epoch [62/120]: Train Loss: 0.4726, Train Acc: 83.87%, Val Loss: 0.6255, Val Acc: 78.13%
# Epoch [63/120]: Train Loss: 0.4729, Train Acc: 83.86%, Val Loss: 0.6247, Val Acc: 78.09%
# Epoch [64/120]: Train Loss: 0.4689, Train Acc: 84.39%, Val Loss: 0.6247, Val Acc: 78.24%
# Epoch [65/120]: Train Loss: 0.4685, Train Acc: 84.17%, Val Loss: 0.6247, Val Acc: 78.01%
# Epoch [66/120]: Train Loss: 0.4709, Train Acc: 84.29%, Val Loss: 0.6251, Val Acc: 78.18%
# Epoch [67/120]: Train Loss: 0.4699, Train Acc: 84.15%, Val Loss: 0.6238, Val Acc: 78.12%
# Epoch [68/120]: Train Loss: 0.4689, Train Acc: 84.13%, Val Loss: 0.6242, Val Acc: 78.23%
# Epoch [69/120]: Train Loss: 0.4639, Train Acc: 84.35%, Val Loss: 0.6230, Val Acc: 78.17%
# Epoch [70/120]: Train Loss: 0.4667, Train Acc: 84.20%, Val Loss: 0.6232, Val Acc: 78.07%
# Epoch [71/120]: Train Loss: 0.4685, Train Acc: 84.30%, Val Loss: 0.6245, Val Acc: 78.10%
# Epoch [72/120]: Train Loss: 0.4664, Train Acc: 84.34%, Val Loss: 0.6238, Val Acc: 78.09%
# Epoch [73/120]: Train Loss: 0.4656, Train Acc: 84.23%, Val Loss: 0.6239, Val Acc: 78.27%
# Epoch [74/120]: Train Loss: 0.4675, Train Acc: 84.18%, Val Loss: 0.6226, Val Acc: 78.12%
# Epoch [75/120]: Train Loss: 0.4697, Train Acc: 84.03%, Val Loss: 0.6218, Val Acc: 78.26%
# Epoch [76/120]: Train Loss: 0.4637, Train Acc: 84.30%, Val Loss: 0.6219, Val Acc: 78.27%
# Epoch [77/120]: Train Loss: 0.4644, Train Acc: 84.36%, Val Loss: 0.6219, Val Acc: 78.36%
# Epoch [78/120]: Train Loss: 0.4667, Train Acc: 84.31%, Val Loss: 0.6215, Val Acc: 78.10%
# Epoch [79/120]: Train Loss: 0.4630, Train Acc: 84.10%, Val Loss: 0.6222, Val Acc: 78.23%
# Epoch [80/120]: Train Loss: 0.4659, Train Acc: 84.22%, Val Loss: 0.6213, Val Acc: 78.14%
# Epoch [81/120]: Train Loss: 0.4637, Train Acc: 84.33%, Val Loss: 0.6220, Val Acc: 78.16%
# Epoch [82/120]: Train Loss: 0.4605, Train Acc: 84.35%, Val Loss: 0.6214, Val Acc: 78.24%
# Epoch [83/120]: Train Loss: 0.4599, Train Acc: 84.61%, Val Loss: 0.6216, Val Acc: 78.19%
# Epoch [84/120]: Train Loss: 0.4619, Train Acc: 84.37%, Val Loss: 0.6218, Val Acc: 78.16%
# Epoch [85/120]: Train Loss: 0.4618, Train Acc: 84.46%, Val Loss: 0.6216, Val Acc: 78.32%
# Epoch [86/120]: Train Loss: 0.4596, Train Acc: 84.57%, Val Loss: 0.6207, Val Acc: 78.29%
# Epoch [87/120]: Train Loss: 0.4607, Train Acc: 84.32%, Val Loss: 0.6209, Val Acc: 78.32%
# Epoch [88/120]: Train Loss: 0.4611, Train Acc: 84.50%, Val Loss: 0.6223, Val Acc: 78.08%
# Epoch [89/120]: Train Loss: 0.4601, Train Acc: 84.59%, Val Loss: 0.6207, Val Acc: 78.26%
# Epoch [90/120]: Train Loss: 0.4617, Train Acc: 84.31%, Val Loss: 0.6207, Val Acc: 78.19%
# Epoch [91/120]: Train Loss: 0.4613, Train Acc: 84.47%, Val Loss: 0.6211, Val Acc: 78.34%
# Epoch [92/120]: Train Loss: 0.4612, Train Acc: 84.31%, Val Loss: 0.6210, Val Acc: 78.29%
# Epoch [93/120]: Train Loss: 0.4614, Train Acc: 84.34%, Val Loss: 0.6212, Val Acc: 78.24%
# Epoch [94/120]: Train Loss: 0.4600, Train Acc: 84.59%, Val Loss: 0.6208, Val Acc: 77.98%
# Epoch [95/120]: Train Loss: 0.4623, Train Acc: 84.19%, Val Loss: 0.6210, Val Acc: 78.29%
# Epoch [96/120]: Train Loss: 0.4593, Train Acc: 84.60%, Val Loss: 0.6207, Val Acc: 78.44%
# Epoch [97/120]: Train Loss: 0.4589, Train Acc: 84.65%, Val Loss: 0.6204, Val Acc: 78.32%
# Epoch [98/120]: Train Loss: 0.4608, Train Acc: 84.41%, Val Loss: 0.6204, Val Acc: 78.23%
# Epoch [99/120]: Train Loss: 0.4603, Train Acc: 84.45%, Val Loss: 0.6205, Val Acc: 78.34%
# Epoch [100/120]: Train Loss: 0.4596, Train Acc: 84.55%, Val Loss: 0.6211, Val Acc: 78.28%
# Epoch [101/120]: Train Loss: 0.4596, Train Acc: 84.41%, Val Loss: 0.6210, Val Acc: 78.11%
# Epoch [102/120]: Train Loss: 0.4579, Train Acc: 84.56%, Val Loss: 0.6208, Val Acc: 78.24%
# Epoch [103/120]: Train Loss: 0.4570, Train Acc: 84.55%, Val Loss: 0.6199, Val Acc: 78.18%
# Epoch [104/120]: Train Loss: 0.4611, Train Acc: 84.47%, Val Loss: 0.6208, Val Acc: 78.26%
# Epoch [105/120]: Train Loss: 0.4599, Train Acc: 84.61%, Val Loss: 0.6209, Val Acc: 78.25%
# Epoch [106/120]: Train Loss: 0.4568, Train Acc: 84.58%, Val Loss: 0.6218, Val Acc: 78.05%
# Epoch [107/120]: Train Loss: 0.4597, Train Acc: 84.50%, Val Loss: 0.6210, Val Acc: 78.05%
# Epoch [108/120]: Train Loss: 0.4613, Train Acc: 84.41%, Val Loss: 0.6205, Val Acc: 78.34%
# Epoch [109/120]: Train Loss: 0.4582, Train Acc: 84.62%, Val Loss: 0.6204, Val Acc: 78.28%
# Epoch [110/120]: Train Loss: 0.4613, Train Acc: 84.46%, Val Loss: 0.6195, Val Acc: 78.23%
# Epoch [111/120]: Train Loss: 0.4558, Train Acc: 84.53%, Val Loss: 0.6206, Val Acc: 78.14%
# Epoch [112/120]: Train Loss: 0.4612, Train Acc: 84.52%, Val Loss: 0.6203, Val Acc: 78.18%
# Epoch [113/120]: Train Loss: 0.4575, Train Acc: 84.52%, Val Loss: 0.6204, Val Acc: 78.26%
# Epoch [114/120]: Train Loss: 0.4585, Train Acc: 84.48%, Val Loss: 0.6199, Val Acc: 78.29%
# Epoch [115/120]: Train Loss: 0.4581, Train Acc: 84.47%, Val Loss: 0.6206, Val Acc: 78.11%
# Epoch [116/120]: Train Loss: 0.4607, Train Acc: 84.47%, Val Loss: 0.6215, Val Acc: 78.12%
# Epoch [117/120]: Train Loss: 0.4559, Train Acc: 84.71%, Val Loss: 0.6200, Val Acc: 78.31%
# Epoch [118/120]: Train Loss: 0.4568, Train Acc: 84.47%, Val Loss: 0.6203, Val Acc: 78.16%
# Epoch [119/120]: Train Loss: 0.4568, Train Acc: 84.58%, Val Loss: 0.6203, Val Acc: 78.20%
# Epoch [120/120]: Train Loss: 0.4576, Train Acc: 84.54%, Val Loss: 0.6198, Val Acc: 78.23%

# %%
def plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Training vs Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Training Accuracy')
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.show()

plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies)

# %%
model.eval()  # Set the model to evaluation mode
test_corrects = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        test_corrects += torch.sum(preds == labels.data)

test_acc = test_corrects.double() / len(test_set)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# Test Accuracy: 0.7853

# %% [markdown]
# ### Observation:
#  1) Each conv layer is followed by batch normalization which helped me in reducing overfitting and enhancing the learning of features. A dropout of 0.3 before the FC layer helped to prevent overfitting further.
#  2) Achieved Accuracy : 78.53
